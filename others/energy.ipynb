# %%
import torch
import os
import shutil
import numpy as np

# %%
import cv2 
  
# Function to extract frames 
def FrameCapture(path): 
    
    frames = []
    # Path to video file 
    vidObj = cv2.VideoCapture(path) 
  
    # Used as counter variable 
    count = 0
  
    # checks whether frames were extracted 
    success = 1
    os.mkdir("frame")
    while success: 
  
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
  
        # Saves the frames with frame-count
        try: 
            cv2.imwrite("frame/frame%d.jpg" % count, image) 
            frames.append(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            count += 1
        except:
            break
    shutil.rmtree("frame")
    return np.array(frames)

# %%
clips_path = '../video_clips/gpAkjSy_8iY/gpAkjSy_8iY.0_0.mp4'
frames = FrameCapture(clips_path)

# %%
delta_rgbs = []
for i in range(len(frames)-1):
    delta_rgbs.append(np.mean(np.array(frames[i,:,:,:] - frames[i+1,:,:,:]) ** 2))

# %%
np.min(delta_rgbs), np.max(delta_rgbs), np.mean(delta_rgbs)
# Out:
# 32.055706380208335

# %%
delta_rgbs
# Out:
# [15.795186993634259,
#  8.299802517361112,
#  19.11973198784722,
#  8.424253472222222,
#  22.25270580150463,
#  9.020435836226852,
#  23.43154984085648,
#  9.342646122685185,
#  24.565692274305555,
#  9.333166232638888,
#  26.240736400462964,
#  9.72419777199074,
#  26.147731843171297,
#  9.706890914351852,
#  27.449887152777777,
#  26.942281539351853,
#  11.258641493055556,
#  27.374829644097222,
#  10.967724609375,
#  27.98987811053241,
#  12.659041883680555,
#  28.56181712962963,
#  12.810933883101852,
#  29.049118561921297,
#  14.994423466435185,
#  28.321207682291668,
#  15.991380570023148,
#  28.643992332175927,
#  16.380185185185184,
#  28.838167317708333,
#  15.42803023726852,
#  29.286810257523147,
#  16.354289641203703,
#  28.027775245949073,
#  15.114292534722223,
#  29.031741898148148,
#  14.647673249421297,
#  28.90685691550926,
#  28.892609953703705,
#  13.653493200231482,
#  29.20213433159722,
#  14.69883716724537,
#  29.48854094328704,
#  13.258595558449073,
# ...
